# %% [markdown]
# 信息熵
# ——不确定程度
# ——发生一个事件得到的信息量大小：
#     信息熵小-得到信息少、掌握信息多-不确定性小
#     信息熵大-得到信息多、掌握信息少-不确定性大
# $$\text{信息熵}H(X)=\sum_{i=1}^n[p(x_i)I(x_i)]=-\sum_{i=1}^n[p(x_i)\ln(p(x_i))].\\
# p(x):x发生的概率\\
# I(x):x发生获取的信息量\\
# p(x_1)=p(x_2)=p(x3)=...=p(x_n)=\frac{1}{n}时，H(X)_{max}=lnn$$

# %% [markdown]
# * 正向化处理（见TOPSIS）
# * 标准化（见TOPSIS）
# * 计算比重/概率
# $$p_{ij}=\frac{\tilde{z}_{ij}}{\sum_{i\operatorname{=}1}^n\tilde{z}_{ij}}$$
# * 计算信息熵
# $$\text{信息熵：}e_j=-{\frac1{\ln n}}\sum_{i=1}^np_{ij}\ln\left(p_{ij}\right)——规范到[0,1]之间\\
#   信息效用值：d_j=1-e_j$$
# * 归一化算熵权
# $$\text{熵权：}W_j=d_j/\sum_{j=1}^md_j$$

# %% [markdown]
# 例：
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

origin = np.asarray([[24, 180, 60, 90, 5000.0],
                     [23, 175, 90, 85, 10000],
                     [23, 170, 95, 92, 8000],
                     [24, 185, 81, 100, 5500],
                     [25, 190, 79, 60, 2000]])
# 正向化
# 年龄：极小-极大
origin[:, 0] = np.max(origin[:, 0]) - origin[:, 0]
# 身高：中间-极大
M = np.max(np.abs(origin[:, 1] - 180))
origin[:, 1] = 1 - (np.abs(origin[:, 1] - 180) * 1.0 / M * 1.0)
# 长相：区间（80-90）-极大
M = max(80 - np.min(origin[:, 2]), np.max(origin[:, 2] - 90))
temp = origin[:, 2]
temp[temp < 80] = 1 - (80 - temp[temp < 80]) / M
mask = np.logical_and(temp >= 80, temp <= 90)
temp[mask] = 1
temp[temp > 90] = 1 - (temp[temp > 90] - 90) / M
origin[:, 2] = temp
# 标准化
origin = origin / np.sqrt(np.sum(np.power(origin, 2), axis=0))
# 计算比重
origin = origin / np.sum(origin, axis=0)
# 计算信息熵
origin[origin == 0] = 0.00001
ej = -1 / np.log(5) * np.sum(origin * np.log(origin), axis=0)
dj = 1 - ej
# 计算权值
Wj = dj / np.sum(dj)
print(Wj)
# Out:
# [0.23286325 0.47418967 0.19110087 0.01125884 0.09058738]
